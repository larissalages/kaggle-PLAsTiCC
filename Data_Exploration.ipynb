# %%
#import everything you need

import pandas as pd
from datetime import datetime

# %%
#Define functions 

def convert_MDJ2unix(df):
    return (df -40587)*86400

def timestamp2readbleTime(time):
    return datetime.utcfromtimestamp(time).strftime('%Y-%m-%d %H:%M:%S')

# %%
#read csv
df_1 = pd.read_csv('training_set.csv')
df_2 = pd.read_csv('training_set_metadata.csv')

# %%
df_1.mjd = convert_MDJ2unix(df_1.mjd)

# %%
df_1[["mjd","passband"]]
# Out:
#                   mjd  passband
# 0        1.655720e+09         2
# 1        1.655720e+09         1
# 2        1.655721e+09         3
# 3        1.655722e+09         4
# 4        1.655891e+09         2
# 5        1.655892e+09         1
# 6        1.655892e+09         3
# 7        1.655893e+09         4
# 8        1.655894e+09         5
# 9        1.657178e+09         2
# 10       1.657178e+09         1
# 11       1.657179e+09         3
# 12       1.657180e+09         4
# 13       1.657181e+09         5
# 14       1.657430e+09         2
# 15       1.657431e+09         1
# 16       1.657431e+09         3
# 17       1.657432e+09         4
# 18       1.657433e+09         5
# 19       1.658216e+09         2
# 20       1.658217e+09         1
# 21       1.658218e+09         3
# 22       1.658219e+09         4
# 23       1.658220e+09         5
# 24       1.658464e+09         2
# 25       1.658465e+09         1
# 26       1.658466e+09         3
# 27       1.658467e+09         4
# 28       1.658468e+09         5
# 29       1.659769e+09         2
# ...               ...       ...
# 1421675  1.717391e+09         2
# 1421676  1.717568e+09         0
# 1421677  1.719633e+09         2
# 1421678  1.719722e+09         1
# 1421679  1.720148e+09         2
# 1421680  1.720237e+09         3
# 1421681  1.720327e+09         3
# 1421682  1.720409e+09         0
# 1421683  1.720752e+09         3
# 1421684  1.720924e+09         2
# 1421685  1.721010e+09         5
# 1421686  1.721365e+09         4
# 1421687  1.721803e+09         5
# 1421688  1.722560e+09         0
# 1421689  1.722649e+09         0
# 1421690  1.722746e+09         3
# 1421691  1.722905e+09         3
# 1421692  1.723084e+09         1
# 1421693  1.723597e+09         5
# 1421694  1.723693e+09         3
# 1421695  1.724116e+09         4
# 1421696  1.724201e+09         4
# 1421697  1.724456e+09         5
# 1421698  1.724542e+09         5
# 1421699  1.724715e+09         4
# 1421700  1.725320e+09         4
# 1421701  1.725671e+09         1
# 1421702  1.726620e+09         5
# 1421703  1.727913e+09         4
# 1421704  1.728090e+09         0
#
# [1421705 rows x 2 columns]

# %%
#0 and 4 have the same passband, I'm trying to see the diference (in days) between the measurements
a = df_1.mjd.iloc[0]
b = df_1.mjd.iloc[1]
c = df_1.mjd.iloc[2]
d = df_1.mjd.iloc[3]
e = df_1.mjd.iloc[4]
f = df_1.mjd.iloc[5]
g = df_1.mjd.iloc[6]
h = df_1.mjd.iloc[7]
i = df_1.mjd.iloc[8]
j = df_1.mjd.iloc[9]
k = df_1.mjd.iloc[10]
l = df_1.mjd.iloc[11]

# %%
print(timestamp2readbleTime(a))
print(timestamp2readbleTime(b))
print(timestamp2readbleTime(c))
print(timestamp2readbleTime(d))
print(timestamp2readbleTime(e))
print(timestamp2readbleTime(f))
print(timestamp2readbleTime(g))
print(timestamp2readbleTime(h))
print(timestamp2readbleTime(i))
print(timestamp2readbleTime(j))
print(timestamp2readbleTime(k))
print(timestamp2readbleTime(l))
# Out:
# 2022-06-20 10:08:58
# 2022-06-20 10:20:03
# 2022-06-20 10:31:09
# 2022-06-20 10:40:48
# 2022-06-22 09:46:04
# 2022-06-22 09:57:10
# 2022-06-22 10:08:15
# 2022-06-22 10:24:05
# 2022-06-22 10:38:38
# 2022-07-07 07:07:23
# 2022-07-07 07:18:28
# 2022-07-07 07:29:34
